# %% [markdown]
# # Gesture Recognition
# In this group project, you are going to build a 3D Conv model that will be able to predict the 5 gestures correctly. Please import the following libraries to get started.

# %%
import numpy as np
import os
from imageio import imread
from skimage.transform import resize
import datetime
#from scipy.misc.pilutil import imread, imresize
import math
import os
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation
from keras.layers import Conv3D, MaxPooling3D
#from keras.layers.convolutional import Conv3D, MaxPooling3D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras import optimizers

# %%
pip install Pillow
# Out:
# Requirement already satisfied: Pillow in c:\users\mathu\anaconda3\lib\site-packages (10.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
np.random.seed(30)
import random as rn
rn.seed(30)
from keras import backend as K
import tensorflow as tf
#tf.set_random_seed(30)
tf.random.set_seed(30)

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the `batch_size` here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %%
# train_doc = np.random.permutation(open('/notebooks/storage/Final_data/Collated_training/train.csv').readlines())
# val_doc = np.random.permutation(open('/notebooks/storage/Final_data/Collated_training/val.csv').readlines())
batch_size = 30
train_doc = np.random.permutation(open('Project_data/Project_data/train.csv').readlines())
val_doc = np.random.permutation(open('Project_data/Project_data/val.csv').readlines())
training_folder = 'Project_data/Project_data/train'
testing_folder = 'Project_data/Project_data/test'

image_sequeneces = range(1,30,2)
image_length = 180
image_breadth = 180

input_shape = (len(image_sequeneces), image_length, image_breadth, 3)


#train_doc.shape
# for n in image_sequeneces:
#     print (n)

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with `img_idx`, `y`,`z` and normalization such that you get high accuracy.

# %%
# model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
#                     callbacks=callbacks_list, validation_data=val_generator, 
#                     validation_steps=validation_steps, class_weight=None,  initial_epoch=0)

# train_generator = generator(train_path, train_doc, batch_size)
# val_generator = generator(val_path, val_doc, batch_size)

def generator(source_path, folder_list, batch_size, is_train = False, augmention = False, debug=False):
    #print( 'Source path = ', source_path, '; batch size =', batch_size, is_train = False, augmention = False, debug=False)
    img_idx = image_sequeneces
    x = len(img_idx)
    y = image_length
    z = image_breadth
#     print ("came here")
    while True:
        t = np.random.permutation(folder_list)
        
        last_batch = 0

        if (len(t)%batch_size) == 0:
            num_batches = int(len(t)/batch_size)
            last_batch = 0
        else:
            last_batch = len(t) - (math.floor(len(t)/batch_size) * batch_size)
            num_batches = len(t)//batch_size + 1
            

#         print ("came here num_batches: " + str(num_batches))
#         print ("came here num_batches: " + str(last_batch))


        for batch in range(num_batches): # we iterate over the number of batches
#             print ("Inside For")
            
            processing_batch_size = batch_size
            if (batch==num_batches-1) and (last_batch>0):
#                 print ("passing last batch")
                processing_batch_size = last_batch
            else:
#                 print ("not last batch")
            
            batch_data = np.zeros((processing_batch_size,x,y,z,3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((processing_batch_size,5)) # batch_labels is the one hot representation of the output
            for folder in range(processing_batch_size): # iterate over the batch_size

                imgs = os.listdir(source_path+'/'+ t[folder + (batch*processing_batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ t[folder + (batch*processing_batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    
                    if image.shape[1] != image.shape[0]:
                        diff_shape = abs(image.shape[1] - image.shape[0])
                        crop_start = diff_shape // 2
                        crop_end = crop_start + min(image.shape[0],image.shape[1])
                        if image.shape[1] > image.shape[0]:
                            image = image[:, crop_start:crop_end]
                        else:
                            image = image[crop_start:crop_end, :]
                            
                    resized_image = resize(image, output_shape=(y,z))
                    
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    
                    batch_data[folder,idx,:,:,0] = resized_image[:,:,0]/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = resized_image[:,:,1]/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = resized_image[:,:,2]/255 #normalise and feed in the image
                    
                batch_labels[folder, int(t[folder + (batch*processing_batch_size)].strip().split(';')[2])] = 1
            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

        
        # write the code for the remaining data points which are left after full batches

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %%
curr_dt_time = datetime.datetime.now()
# train_path = '/notebooks/storage/Final_data/Collated_training/train'
# val_path = '/notebooks/storage/Final_data/Collated_training/val'
train_path = 'Project_data/Project_data/train'
val_path = 'Project_data/Project_data/val'
#Project_data/Project_data
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
num_epochs = 10 # choose the number of epochs
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 10

# %% [markdown]
# ## Model
# Here you make the model using different functionalities that Keras provides. Remember to use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. You would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %%
#write your model here
model = Sequential()
model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
model.add(MaxPooling3D(pool_size=2))

model.add(Conv3D(64, kernel_size=3, activation='relu'))
model.add(MaxPooling3D(pool_size=2))

model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(5, activation='softmax'))

# %% [markdown]
# Now that you have written the model, the next step is to `compile` the model. When you print the `summary` of the model, you'll see the total number of parameters you have to train.

# %%
optimiser = optimizers.Adam(learning_rate=0.01)

model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv3d_2 (Conv3D)                    │ (None, 13, 178, 178, 32)    │           2,624 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling3d_2 (MaxPooling3D)       │ (None, 6, 89, 89, 32)       │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv3d_3 (Conv3D)                    │ (None, 4, 87, 87, 64)       │          55,360 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling3d_3 (MaxPooling3D)       │ (None, 2, 43, 43, 64)       │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 236672)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 256)                 │      60,588,288 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 5)                   │           1,285 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 60,647,557 (231.35 MB)
#  Trainable params: 60,647,557 (231.35 MB)
#  Non-trainable params: 0 (0.00 B)
# None

# %% [markdown]
# Let us create the `train_generator` and the `val_generator` which will be used in `.fit_generator`.

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5' + '.keras'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto')
#checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto')

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.001, verbose=1) # write the REducelronplateau code here
callbacks_list = [checkpoint, LR]

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %% [markdown]
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
# history = model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
#                     callbacks=callbacks_list, validation_data=val_generator, 
#                     validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)

model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None,  initial_epoch=0)
# Out:
# came here
# came here num_batches: 23
# came here num_batches: 3
# Inside For
# not last batch
# C:\Users\mathu\AppData\Local\Temp\ipykernel_12232\3628453760.py:41: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread(source_path+'/'+ t[folder + (batch*processing_batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# Inside For
# not last batch
# Epoch 1/10
#  1/23 ━━━━━━━━━━━━━━━━━━━━ 2:34 7s/step - categorical_accuracy: 0.2000 - loss: 1.6316Inside For
# not last batch
#  2/23 ━━━━━━━━━━━━━━━━━━━━ 1:16 4s/step - categorical_accuracy: 0.1750 - loss: 984.6618Inside For
# not last batch
#  3/23 ━━━━━━━━━━━━━━━━━━━━ 1:39 5s/step - categorical_accuracy: 0.1796 - loss: 1101.0704Inside For
# not last batch
#  4/23 ━━━━━━━━━━━━━━━━━━━━ 1:46 6s/step - categorical_accuracy: 0.1826 - loss: 1076.2157Inside For
# not last batch
#  5/23 ━━━━━━━━━━━━━━━━━━━━ 1:43 6s/step - categorical_accuracy: 0.1808 - loss: 1021.3224Inside For
# not last batch
#  6/23 ━━━━━━━━━━━━━━━━━━━━ 1:38 6s/step - categorical_accuracy: 0.1784 - loss: 962.5139 Inside For
# not last batch
#  7/23 ━━━━━━━━━━━━━━━━━━━━ 1:33 6s/step - categorical_accuracy: 0.1774 - loss: 906.8997Inside For
# not last batch
#  8/23 ━━━━━━━━━━━━━━━━━━━━ 1:28 6s/step - categorical_accuracy: 0.1756 - loss: 856.2579Inside For
# not last batch
#  9/23 ━━━━━━━━━━━━━━━━━━━━ 1:22 6s/step - categorical_accuracy: 0.1750 - loss: 810.6950Inside For
# not last batch
# 10/23 ━━━━━━━━━━━━━━━━━━━━ 1:17 6s/step - categorical_accuracy: 0.1748 - loss: 769.7988Inside For
# not last batch
# 11/23 ━━━━━━━━━━━━━━━━━━━━ 1:12 6s/step - categorical_accuracy: 0.1752 - loss: 733.0314Inside For
# not last batch
# 12/23 ━━━━━━━━━━━━━━━━━━━━ 1:08 6s/step - categorical_accuracy: 0.1754 - loss: 699.8658Inside For
# not last batch
# 13/23 ━━━━━━━━━━━━━━━━━━━━ 1:03 6s/step - categorical_accuracy: 0.1759 - loss: 669.8298Inside For
# not last batch
# 14/23 ━━━━━━━━━━━━━━━━━━━━ 57s 6s/step - categorical_accuracy: 0.1766 - loss: 642.5142 Inside For
# not last batch
# 15/23 ━━━━━━━━━━━━━━━━━━━━ 51s 6s/step - categorical_accuracy: 0.1776 - loss: 617.5705Inside For
# not last batch
# 16/23 ━━━━━━━━━━━━━━━━━━━━ 44s 6s/step - categorical_accuracy: 0.1785 - loss: 594.7028Inside For
# not last batch
# 17/23 ━━━━━━━━━━━━━━━━━━━━ 38s 6s/step - categorical_accuracy: 0.1793 - loss: 573.6602Inside For
# not last batch
# 18/23 ━━━━━━━━━━━━━━━━━━━━ 31s 6s/step - categorical_accuracy: 0.1799 - loss: 554.2292Inside For
# not last batch
# 19/23 ━━━━━━━━━━━━━━━━━━━━ 25s 6s/step - categorical_accuracy: 0.1803 - loss: 536.2278Inside For
# not last batch
# 20/23 ━━━━━━━━━━━━━━━━━━━━ 19s 6s/step - categorical_accuracy: 0.1805 - loss: 519.5001Inside For
# not last batch
# 21/23 ━━━━━━━━━━━━━━━━━━━━ 12s 6s/step - categorical_accuracy: 0.1809 - loss: 503.9118Inside For
# passing last batch
# came here num_batches: 23
# came here num_batches: 3
# Inside For
# not last batch
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - categorical_accuracy: 0.1816 - loss: 476.0129came here
# came here num_batches: 4
# came here num_batches: 10
# Inside For
# not last batch
# Inside For
# not last batch
# Inside For
# not last batch
# Inside For
# not last batch
# Inside For
# passing last batch
# came here num_batches: 4
# came here num_batches: 10
# Inside For
# not last batch
#
# Epoch 1: saving model to model_init_2024-12-1414_16_12.083301/model-00001-182.66342-0.18854-1.61097-0.22000.h5.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 166s 7s/step - categorical_accuracy: 0.1819 - loss: 463.7900 - val_categorical_accuracy: 0.2200 - val_loss: 1.6110 - learning_rate: 0.0100
# Epoch 2/10
# Inside For
# not last batch
#  2/23 ━━━━━━━━━━━━━━━━━━━━ 1:17 4s/step - categorical_accuracy: 0.1667 - loss: 1.6171Inside For
# not last batch
# Inside For
# not last batch
#  3/23 ━━━━━━━━━━━━━━━━━━━━ 1:55 6s/step - categorical_accuracy: 0.1852 - loss: 1.6157Inside For
# not last batch
#  4/23 ━━━━━━━━━━━━━━━━━━━━ 1:59 6s/step - categorical_accuracy: 0.1972 - loss: 1.6147Inside For
# not last batch
#  5/23 ━━━━━━━━━━━━━━━━━━━━ 1:56 6s/step - categorical_accuracy: 0.2071 - loss: 1.6140Inside For
# not last batch
#  6/23 ━━━━━━━━━━━━━━━━━━━━ 1:49 6s/step - categorical_accuracy: 0.2106 - loss: 1.6135Inside For
# not last batch
#  7/23 ━━━━━━━━━━━━━━━━━━━━ 1:43 6s/step - categorical_accuracy: 0.2111 - loss: 1.6131Inside For
# not last batch
#  8/23 ━━━━━━━━━━━━━━━━━━━━ 1:37 6s/step - categorical_accuracy: 0.2107 - loss: 1.6128Inside For
# not last batch
#  9/23 ━━━━━━━━━━━━━━━━━━━━ 1:30 6s/step - categorical_accuracy: 0.2112 - loss: 1.6125Inside For
# not last batch
# 10/23 ━━━━━━━━━━━━━━━━━━━━ 1:23 6s/step - categorical_accuracy: 0.2111 - loss: 1.6122Inside For
# not last batch
# 11/23 ━━━━━━━━━━━━━━━━━━━━ 1:16 6s/step - categorical_accuracy: 0.2103 - loss: 1.6121Inside For
# not last batch
# 12/23 ━━━━━━━━━━━━━━━━━━━━ 1:10 6s/step - categorical_accuracy: 0.2095 - loss: 1.6119Inside For
# not last batch
# 13/23 ━━━━━━━━━━━━━━━━━━━━ 1:04 6s/step - categorical_accuracy: 0.2082 - loss: 1.6118Inside For
# not last batch
# 14/23 ━━━━━━━━━━━━━━━━━━━━ 58s 6s/step - categorical_accuracy: 0.2071 - loss: 1.6117 Inside For
# not last batch
# 15/23 ━━━━━━━━━━━━━━━━━━━━ 51s 6s/step - categorical_accuracy: 0.2060 - loss: 1.6116Inside For
# not last batch
# 16/23 ━━━━━━━━━━━━━━━━━━━━ 45s 6s/step - categorical_accuracy: 0.2051 - loss: 1.6116Inside For
# not last batch
# 17/23 ━━━━━━━━━━━━━━━━━━━━ 38s 6s/step - categorical_accuracy: 0.2041 - loss: 1.6116Inside For
# not last batch
# 18/23 ━━━━━━━━━━━━━━━━━━━━ 32s 6s/step - categorical_accuracy: 0.2032 - loss: 1.6116Inside For
# not last batch
# 19/23 ━━━━━━━━━━━━━━━━━━━━ 26s 7s/step - categorical_accuracy: 0.2023 - loss: 1.6116Inside For
# not last batch
# 20/23 ━━━━━━━━━━━━━━━━━━━━ 19s 7s/step - categorical_accuracy: 0.2014 - loss: 1.6116Inside For
# not last batch
# 21/23 ━━━━━━━━━━━━━━━━━━━━ 13s 7s/step - categorical_accuracy: 0.2007 - loss: 1.6116Inside For
# passing last batch
# came here num_batches: 23
# came here num_batches: 3
# Inside For
# not last batch
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - categorical_accuracy: 0.1995 - loss: 1.6116Inside For
# not last batch
# Inside For
# not last batch
# Inside For
# passing last batch
# came here num_batches: 4
# came here num_batches: 10
# Inside For
# not last batch
#
# Epoch 2: saving model to model_init_2024-12-1414_16_12.083301/model-00002-1.61165-0.18703-1.60746-0.22000.h5.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 154s 7s/step - categorical_accuracy: 0.1990 - loss: 1.6116 - val_categorical_accuracy: 0.2200 - val_loss: 1.6075 - learning_rate: 0.0100
# Epoch 3/10
#  1/23 ━━━━━━━━━━━━━━━━━━━━ 1:25 4s/step - categorical_accuracy: 0.1667 - loss: 1.6098Inside For
# not last batch
#  2/23 ━━━━━━━━━━━━━━━━━━━━ 1:24 4s/step - categorical_accuracy: 0.1500 - loss: 1.6101Inside For
# not last batch
# Inside For
# not last batch
#  3/23 ━━━━━━━━━━━━━━━━━━━━ 2:03 6s/step - categorical_accuracy: 0.1519 - loss: 1.6103Inside For
# not last batch
#  4/23 ━━━━━━━━━━━━━━━━━━━━ 2:08 7s/step - categorical_accuracy: 0.1556 - loss: 1.6104Inside For
# not last batch
#  5/23 ━━━━━━━━━━━━━━━━━━━━ 1:59 7s/step - categorical_accuracy: 0.1618 - loss: 1.6103Inside For
# not last batch
#  6/23 ━━━━━━━━━━━━━━━━━━━━ 1:53 7s/step - categorical_accuracy: 0.1654 - loss: 1.6103Inside For
# not last batch
#  7/23 ━━━━━━━━━━━━━━━━━━━━ 1:46 7s/step - categorical_accuracy: 0.1730 - loss: 1.6100Inside For
# not last batch
#  8/23 ━━━━━━━━━━━━━━━━━━━━ 1:39 7s/step - categorical_accuracy: 0.1801 - loss: 1.6097Inside For
# not last batch
#  9/23 ━━━━━━━━━━━━━━━━━━━━ 1:32 7s/step - categorical_accuracy: 0.1852 - loss: 1.6095Inside For
# not last batch
# 10/23 ━━━━━━━━━━━━━━━━━━━━ 1:24 7s/step - categorical_accuracy: 0.1890 - loss: 1.6094Inside For
# not last batch
# 11/23 ━━━━━━━━━━━━━━━━━━━━ 1:18 7s/step - categorical_accuracy: 0.1925 - loss: 1.6093Inside For
# not last batch
# 12/23 ━━━━━━━━━━━━━━━━━━━━ 1:12 7s/step - categorical_accuracy: 0.1949 - loss: 1.6092Inside For
# not last batch
# 13/23 ━━━━━━━━━━━━━━━━━━━━ 1:06 7s/step - categorical_accuracy: 0.1971 - loss: 1.6092Inside For
# not last batch
# 14/23 ━━━━━━━━━━━━━━━━━━━━ 59s 7s/step - categorical_accuracy: 0.1982 - loss: 1.6092 Inside For
# not last batch
# 15/23 ━━━━━━━━━━━━━━━━━━━━ 53s 7s/step - categorical_accuracy: 0.1995 - loss: 1.6092Inside For
# not last batch
# 16/23 ━━━━━━━━━━━━━━━━━━━━ 46s 7s/step - categorical_accuracy: 0.2004 - loss: 1.6093Inside For
# not last batch
# 17/23 ━━━━━━━━━━━━━━━━━━━━ 39s 7s/step - categorical_accuracy: 0.2010 - loss: 1.6093Inside For
# not last batch
# 18/23 ━━━━━━━━━━━━━━━━━━━━ 33s 7s/step - categorical_accuracy: 0.2012 - loss: 1.6094Inside For
# not last batch
# 19/23 ━━━━━━━━━━━━━━━━━━━━ 26s 7s/step - categorical_accuracy: 0.2013 - loss: 1.6095Inside For
# not last batch
# 20/23 ━━━━━━━━━━━━━━━━━━━━ 19s 7s/step - categorical_accuracy: 0.2013 - loss: 1.6096Inside For
# not last batch
# 21/23 ━━━━━━━━━━━━━━━━━━━━ 13s 7s/step - categorical_accuracy: 0.2014 - loss: 1.6097Inside For
# passing last batch
# came here num_batches: 23
# came here num_batches: 3
# Inside For
# not last batch
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - categorical_accuracy: 0.2015 - loss: 1.6098Inside For
# not last batch
# Inside For
# not last batch
# Inside For
# passing last batch
# came here num_batches: 4
# came here num_batches: 10
# Inside For
# not last batch
#
# Epoch 3: saving model to model_init_2024-12-1414_16_12.083301/model-00003-1.61112-0.20211-1.60976-0.21000.h5.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 156s 7s/step - categorical_accuracy: 0.2016 - loss: 1.6098 - val_categorical_accuracy: 0.2100 - val_loss: 1.6098 - learning_rate: 0.0100
# Epoch 4/10
#  1/23 ━━━━━━━━━━━━━━━━━━━━ 1:21 4s/step - categorical_accuracy: 0.2333 - loss: 1.6066Inside For
# not last batch
#  2/23 ━━━━━━━━━━━━━━━━━━━━ 1:16 4s/step - categorical_accuracy: 0.2333 - loss: 1.6056Inside For
# not last batch
# Inside For
# not last batch
#  3/23 ━━━━━━━━━━━━━━━━━━━━ 2:11 7s/step - categorical_accuracy: 0.2259 - loss: 1.6061Inside For
# not last batch
#  4/23 ━━━━━━━━━━━━━━━━━━━━ 2:07 7s/step - categorical_accuracy: 0.2215 - loss: 1.6065Inside For
# not last batch
#  5/23 ━━━━━━━━━━━━━━━━━━━━ 1:58 7s/step - categorical_accuracy: 0.2199 - loss: 1.6070Inside For
# not last batch
#  6/23 ━━━━━━━━━━━━━━━━━━━━ 1:51 7s/step - categorical_accuracy: 0.2184 - loss: 1.6074Inside For
# not last batch
#  7/23 ━━━━━━━━━━━━━━━━━━━━ 1:45 7s/step - categorical_accuracy: 0.2199 - loss: 1.6076Inside For
# not last batch
#  8/23 ━━━━━━━━━━━━━━━━━━━━ 1:39 7s/step - categorical_accuracy: 0.2200 - loss: 1.6077Inside For
# not last batch
#  9/23 ━━━━━━━━━━━━━━━━━━━━ 1:32 7s/step - categorical_accuracy: 0.2202 - loss: 1.6079Inside For
# not last batch
# 10/23 ━━━━━━━━━━━━━━━━━━━━ 1:26 7s/step - categorical_accuracy: 0.2209 - loss: 1.6081Inside For
# not last batch
# 11/23 ━━━━━━━━━━━━━━━━━━━━ 1:20 7s/step - categorical_accuracy: 0.2212 - loss: 1.6082Inside For
# not last batch
# 12/23 ━━━━━━━━━━━━━━━━━━━━ 1:13 7s/step - categorical_accuracy: 0.2206 - loss: 1.6083Inside For
# not last batch
# 13/23 ━━━━━━━━━━━━━━━━━━━━ 1:06 7s/step - categorical_accuracy: 0.2200 - loss: 1.6084Inside For
# not last batch
# 14/23 ━━━━━━━━━━━━━━━━━━━━ 59s 7s/step - categorical_accuracy: 0.2192 - loss: 1.6085 Inside For
# not last batch
# 15/23 ━━━━━━━━━━━━━━━━━━━━ 52s 7s/step - categorical_accuracy: 0.2184 - loss: 1.6086Inside For
# not last batch
# 16/23 ━━━━━━━━━━━━━━━━━━━━ 46s 7s/step - categorical_accuracy: 0.2178 - loss: 1.6086Inside For
# not last batch
# 17/23 ━━━━━━━━━━━━━━━━━━━━ 39s 7s/step - categorical_accuracy: 0.2173 - loss: 1.6087Inside For
# not last batch
# 18/23 ━━━━━━━━━━━━━━━━━━━━ 33s 7s/step - categorical_accuracy: 0.2164 - loss: 1.6088Inside For
# not last batch
# 19/23 ━━━━━━━━━━━━━━━━━━━━ 26s 7s/step - categorical_accuracy: 0.2158 - loss: 1.6088Inside For
# not last batch
# 20/23 ━━━━━━━━━━━━━━━━━━━━ 19s 7s/step - categorical_accuracy: 0.2151 - loss: 1.6088Inside For
# not last batch
# 21/23 ━━━━━━━━━━━━━━━━━━━━ 13s 7s/step - categorical_accuracy: 0.2147 - loss: 1.6089Inside For
# passing last batch
# came here num_batches: 23
# came here num_batches: 3
# Inside For
# not last batch
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - categorical_accuracy: 0.2141 - loss: 1.6090Inside For
# not last batch
# Inside For
# not last batch
# Inside For
# passing last batch
# came here num_batches: 4
# came here num_batches: 10
# Inside For
# not last batch
#
# Epoch 4: saving model to model_init_2024-12-1414_16_12.083301/model-00004-1.61001-0.20664-1.61071-0.20000.h5.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 157s 7s/step - categorical_accuracy: 0.2138 - loss: 1.6090 - val_categorical_accuracy: 0.2000 - val_loss: 1.6107 - learning_rate: 0.0100
# Epoch 5/10
#  1/23 ━━━━━━━━━━━━━━━━━━━━ 1:29 4s/step - categorical_accuracy: 0.2000 - loss: 1.6090Inside For
# not last batch
#  2/23 ━━━━━━━━━━━━━━━━━━━━ 1:49 5s/step - categorical_accuracy: 0.2000 - loss: 1.6092Inside For
# not last batch
# Inside For
# not last batch
#  3/23 ━━━━━━━━━━━━━━━━━━━━ 2:20 7s/step - categorical_accuracy: 0.2000 - loss: 1.6092Inside For
# not last batch
#  4/23 ━━━━━━━━━━━━━━━━━━━━ 2:21 7s/step - categorical_accuracy: 0.1917 - loss: 1.6094Inside For
# not last batch
#  5/23 ━━━━━━━━━━━━━━━━━━━━ 2:13 7s/step - categorical_accuracy: 0.1840 - loss: 1.6095Inside For
# not last batch
#  6/23 ━━━━━━━━━━━━━━━━━━━━ 2:06 7s/step - categorical_accuracy: 0.1820 - loss: 1.6095Inside For
# not last batch
#  7/23 ━━━━━━━━━━━━━━━━━━━━ 1:57 7s/step - categorical_accuracy: 0.1819 - loss: 1.6095Inside For
# not last batch
#  8/23 ━━━━━━━━━━━━━━━━━━━━ 1:48 7s/step - categorical_accuracy: 0.1836 - loss: 1.6094Inside For
# not last batch
#  9/23 ━━━━━━━━━━━━━━━━━━━━ 1:40 7s/step - categorical_accuracy: 0.1854 - loss: 1.6094Inside For
# not last batch
# 10/23 ━━━━━━━━━━━━━━━━━━━━ 1:31 7s/step - categorical_accuracy: 0.1866 - loss: 1.6095Inside For
# not last batch
# 11/23 ━━━━━━━━━━━━━━━━━━━━ 1:24 7s/step - categorical_accuracy: 0.1867 - loss: 1.6095Inside For
# not last batch
# 12/23 ━━━━━━━━━━━━━━━━━━━━ 1:16 7s/step - categorical_accuracy: 0.1871 - loss: 1.6095Inside For
# not last batch
# 13/23 ━━━━━━━━━━━━━━━━━━━━ 1:09 7s/step - categorical_accuracy: 0.1873 - loss: 1.6096Inside For
# not last batch
# 14/23 ━━━━━━━━━━━━━━━━━━━━ 1:02 7s/step - categorical_accuracy: 0.1872 - loss: 1.6096Inside For
# not last batch
# 15/23 ━━━━━━━━━━━━━━━━━━━━ 54s 7s/step - categorical_accuracy: 0.1875 - loss: 1.6096 Inside For
# not last batch
# 16/23 ━━━━━━━━━━━━━━━━━━━━ 48s 7s/step - categorical_accuracy: 0.1875 - loss: 1.6097Inside For
# not last batch
# 17/23 ━━━━━━━━━━━━━━━━━━━━ 41s 7s/step - categorical_accuracy: 0.1872 - loss: 1.6097Inside For
# not last batch
# 18/23 ━━━━━━━━━━━━━━━━━━━━ 34s 7s/step - categorical_accuracy: 0.1874 - loss: 1.6097Inside For
# not last batch
# 19/23 ━━━━━━━━━━━━━━━━━━━━ 27s 7s/step - categorical_accuracy: 0.1875 - loss: 1.6097Inside For
# not last batch
# 20/23 ━━━━━━━━━━━━━━━━━━━━ 20s 7s/step - categorical_accuracy: 0.1873 - loss: 1.6098Inside For
# not last batch
# 21/23 ━━━━━━━━━━━━━━━━━━━━ 13s 7s/step - categorical_accuracy: 0.1873 - loss: 1.6098Inside For
# passing last batch
# came here num_batches: 23
# came here num_batches: 3
# Inside For
# not last batch
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - categorical_accuracy: 0.1870 - loss: 1.6099Inside For
# not last batch
# Inside For
# not last batch
# Inside For
# passing last batch
# came here num_batches: 4
# came here num_batches: 10
# Inside For
# not last batch
#
# Epoch 5: saving model to model_init_2024-12-1414_16_12.083301/model-00005-1.61062-0.18401-1.61025-0.16000.h5.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 161s 7s/step - categorical_accuracy: 0.1868 - loss: 1.6099 - val_categorical_accuracy: 0.1600 - val_loss: 1.6102 - learning_rate: 0.0100
# Epoch 6/10
# Inside For
# not last batch
#  2/23 ━━━━━━━━━━━━━━━━━━━━ 1:20 4s/step - categorical_accuracy: 0.1667 - loss: 1.6107Inside For
# not last batch
# Inside For
# not last batch
#  3/23 ━━━━━━━━━━━━━━━━━━━━ 2:04 6s/step - categorical_accuracy: 0.1741 - loss: 1.6104Inside For
# not last batch
#  4/23 ━━━━━━━━━━━━━━━━━━━━ 2:08 7s/step - categorical_accuracy: 0.1743 - loss: 1.6104Inside For
# not last batch
#  5/23 ━━━━━━━━━━━━━━━━━━━━ 2:04 7s/step - categorical_accuracy: 0.1781 - loss: 1.6104Inside For
# not last batch
#  6/23 ━━━━━━━━━━━━━━━━━━━━ 1:58 7s/step - categorical_accuracy: 0.1855 - loss: 1.6102Inside For
# not last batch
#  7/23 ━━━━━━━━━━━━━━━━━━━━ 1:50 7s/step - categorical_accuracy: 0.1923 - loss: 1.6101Inside For
# not last batch
#  8/23 ━━━━━━━━━━━━━━━━━━━━ 1:42 7s/step - categorical_accuracy: 0.1948 - loss: 1.6100Inside For
# not last batch
#  9/23 ━━━━━━━━━━━━━━━━━━━━ 1:35 7s/step - categorical_accuracy: 0.1966 - loss: 1.6098Inside For
# not last batch
# 10/23 ━━━━━━━━━━━━━━━━━━━━ 1:28 7s/step - categorical_accuracy: 0.1976 - loss: 1.6098Inside For
# not last batch
# 11/23 ━━━━━━━━━━━━━━━━━━━━ 1:21 7s/step - categorical_accuracy: 0.1984 - loss: 1.6098Inside For
# not last batch
# 12/23 ━━━━━━━━━━━━━━━━━━━━ 1:14 7s/step - categorical_accuracy: 0.1999 - loss: 1.6098Inside For
# not last batch
# 13/23 ━━━━━━━━━━━━━━━━━━━━ 1:07 7s/step - categorical_accuracy: 0.2003 - loss: 1.6098Inside For
# not last batch
# 14/23 ━━━━━━━━━━━━━━━━━━━━ 1:00 7s/step - categorical_accuracy: 0.2006 - loss: 1.6098Inside For
# not last batch
# 15/23 ━━━━━━━━━━━━━━━━━━━━ 53s 7s/step - categorical_accuracy: 0.2021 - loss: 1.6097 Inside For
# not last batch
# 16/23 ━━━━━━━━━━━━━━━━━━━━ 46s 7s/step - categorical_accuracy: 0.2036 - loss: 1.6096Inside For
# not last batch
# 17/23 ━━━━━━━━━━━━━━━━━━━━ 39s 7s/step - categorical_accuracy: 0.2045 - loss: 1.6095Inside For
# not last batch
# 18/23 ━━━━━━━━━━━━━━━━━━━━ 33s 7s/step - categorical_accuracy: 0.2049 - loss: 1.6095Inside For
# not last batch
# 19/23 ━━━━━━━━━━━━━━━━━━━━ 26s 7s/step - categorical_accuracy: 0.2053 - loss: 1.6095Inside For
# not last batch
# 20/23 ━━━━━━━━━━━━━━━━━━━━ 19s 7s/step - categorical_accuracy: 0.2056 - loss: 1.6095Inside For
# not last batch
# 21/23 ━━━━━━━━━━━━━━━━━━━━ 13s 7s/step - categorical_accuracy: 0.2054 - loss: 1.6096Inside For
# passing last batch
# came here num_batches: 23
# came here num_batches: 3
# Inside For
# not last batch
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - categorical_accuracy: 0.2053 - loss: 1.6096Inside For
# not last batch
# Inside For
# not last batch
# Inside For
# passing last batch
# came here num_batches: 4
# came here num_batches: 10
# Inside For
# not last batch
#
# Epoch 6: saving model to model_init_2024-12-1414_16_12.083301/model-00006-1.61005-0.20362-1.60872-0.19000.h5.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 157s 7s/step - categorical_accuracy: 0.2053 - loss: 1.6096 - val_categorical_accuracy: 0.1900 - val_loss: 1.6087 - learning_rate: 0.0100
# Epoch 7/10
# Inside For
# not last batch
#  2/23 ━━━━━━━━━━━━━━━━━━━━ 1:13 4s/step - categorical_accuracy: 0.1750 - loss: 1.6110Inside For
# not last batch
# Inside For
# not last batch
#  3/23 ━━━━━━━━━━━━━━━━━━━━ 1:49 5s/step - categorical_accuracy: 0.1759 - loss: 1.6117Inside For
# not last batch
#  4/23 ━━━━━━━━━━━━━━━━━━━━ 2:02 6s/step - categorical_accuracy: 0.1757 - loss: 1.6116Inside For
# not last batch
#  5/23 ━━━━━━━━━━━━━━━━━━━━ 1:55 6s/step - categorical_accuracy: 0.1699 - loss: 1.6117Inside For
# not last batch
#  6/23 ━━━━━━━━━━━━━━━━━━━━ 1:48 6s/step - categorical_accuracy: 0.1666 - loss: 1.6117Inside For
# not last batch
#  7/23 ━━━━━━━━━━━━━━━━━━━━ 1:41 6s/step - categorical_accuracy: 0.1652 - loss: 1.6116Inside For
# not last batch
#  8/23 ━━━━━━━━━━━━━━━━━━━━ 1:34 6s/step - categorical_accuracy: 0.1644 - loss: 1.6115Inside For
# not last batch
#  9/23 ━━━━━━━━━━━━━━━━━━━━ 1:28 6s/step - categorical_accuracy: 0.1630 - loss: 1.6114Inside For
# not last batch
# 10/23 ━━━━━━━━━━━━━━━━━━━━ 1:21 6s/step - categorical_accuracy: 0.1627 - loss: 1.6113Inside For
# not last batch
# 11/23 ━━━━━━━━━━━━━━━━━━━━ 1:15 6s/step - categorical_accuracy: 0.1633 - loss: 1.6112Inside For
# not last batch
# 12/23 ━━━━━━━━━━━━━━━━━━━━ 1:09 6s/step - categorical_accuracy: 0.1641 - loss: 1.6112Inside For
# not last batch
# 13/23 ━━━━━━━━━━━━━━━━━━━━ 1:02 6s/step - categorical_accuracy: 0.1654 - loss: 1.6111Inside For
# not last batch
# 14/23 ━━━━━━━━━━━━━━━━━━━━ 56s 6s/step - categorical_accuracy: 0.1671 - loss: 1.6110 Inside For
# not last batch
# 15/23 ━━━━━━━━━━━━━━━━━━━━ 50s 6s/step - categorical_accuracy: 0.1682 - loss: 1.6109Inside For
# not last batch
# 16/23 ━━━━━━━━━━━━━━━━━━━━ 43s 6s/step - categorical_accuracy: 0.1699 - loss: 1.6108Inside For
# not last batch
# 17/23 ━━━━━━━━━━━━━━━━━━━━ 37s 6s/step - categorical_accuracy: 0.1714 - loss: 1.6107Inside For
# not last batch
# 18/23 ━━━━━━━━━━━━━━━━━━━━ 31s 6s/step - categorical_accuracy: 0.1724 - loss: 1.6107Inside For
# not last batch
# 19/23 ━━━━━━━━━━━━━━━━━━━━ 25s 6s/step - categorical_accuracy: 0.1733 - loss: 1.6106Inside For
# not last batch
# 20/23 ━━━━━━━━━━━━━━━━━━━━ 18s 6s/step - categorical_accuracy: 0.1739 - loss: 1.6106Inside For
# not last batch
# 21/23 ━━━━━━━━━━━━━━━━━━━━ 12s 6s/step - categorical_accuracy: 0.1743 - loss: 1.6106Inside For
# passing last batch
# came here num_batches: 23
# came here num_batches: 3
# Inside For
# not last batch
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - categorical_accuracy: 0.1747 - loss: 1.6105Inside For
# not last batch
# Inside For
# not last batch
# Inside For
# passing last batch
# came here num_batches: 4
# came here num_batches: 10
# Inside For
# not last batch
#
# Epoch 7: saving model to model_init_2024-12-1414_16_12.083301/model-00007-1.61026-0.17949-1.60779-0.24000.h5.keras
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0019999999552965165.
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 150s 7s/step - categorical_accuracy: 0.1749 - loss: 1.6105 - val_categorical_accuracy: 0.2400 - val_loss: 1.6078 - learning_rate: 0.0100
# Epoch 8/10
# Inside For
# not last batch
#  2/23 ━━━━━━━━━━━━━━━━━━━━ 1:14 4s/step - categorical_accuracy: 0.1167 - loss: 1.6125Inside For
# not last batch
# Inside For
# not last batch
#  3/23 ━━━━━━━━━━━━━━━━━━━━ 1:48 5s/step - categorical_accuracy: 0.1407 - loss: 1.6118Inside For
# not last batch
#  4/23 ━━━━━━━━━━━━━━━━━━━━ 1:58 6s/step - categorical_accuracy: 0.1514 - loss: 1.6114Inside For
# not last batch
#  5/23 ━━━━━━━━━━━━━━━━━━━━ 1:50 6s/step - categorical_accuracy: 0.1584 - loss: 1.6111Inside For
# not last batch
#  6/23 ━━━━━━━━━━━━━━━━━━━━ 1:44 6s/step - categorical_accuracy: 0.1644 - loss: 1.6109Inside For
# not last batch
#  7/23 ━━━━━━━━━━━━━━━━━━━━ 1:37 6s/step - categorical_accuracy: 0.1682 - loss: 1.6107Inside For
# not last batch
#  8/23 ━━━━━━━━━━━━━━━━━━━━ 1:31 6s/step - categorical_accuracy: 0.1685 - loss: 1.6106Inside For
# not last batch
#  9/23 ━━━━━━━━━━━━━━━━━━━━ 1:26 6s/step - categorical_accuracy: 0.1691 - loss: 1.6106Inside For
# not last batch
# 10/23 ━━━━━━━━━━━━━━━━━━━━ 1:20 6s/step - categorical_accuracy: 0.1705 - loss: 1.6105Inside For
# not last batch
# 11/23 ━━━━━━━━━━━━━━━━━━━━ 1:14 6s/step - categorical_accuracy: 0.1721 - loss: 1.6105Inside For
# not last batch
# 12/23 ━━━━━━━━━━━━━━━━━━━━ 1:08 6s/step - categorical_accuracy: 0.1733 - loss: 1.6104Inside For
# not last batch
# 13/23 ━━━━━━━━━━━━━━━━━━━━ 1:01 6s/step - categorical_accuracy: 0.1738 - loss: 1.6103Inside For
# not last batch
# 14/23 ━━━━━━━━━━━━━━━━━━━━ 56s 6s/step - categorical_accuracy: 0.1741 - loss: 1.6103 Inside For
# not last batch
# 15/23 ━━━━━━━━━━━━━━━━━━━━ 49s 6s/step - categorical_accuracy: 0.1748 - loss: 1.6102Inside For
# not last batch
# 16/23 ━━━━━━━━━━━━━━━━━━━━ 43s 6s/step - categorical_accuracy: 0.1753 - loss: 1.6102Inside For
# not last batch
# 17/23 ━━━━━━━━━━━━━━━━━━━━ 37s 6s/step - categorical_accuracy: 0.1764 - loss: 1.6102Inside For
# not last batch
# 18/23 ━━━━━━━━━━━━━━━━━━━━ 31s 6s/step - categorical_accuracy: 0.1775 - loss: 1.6101Inside For
# not last batch
# 19/23 ━━━━━━━━━━━━━━━━━━━━ 25s 6s/step - categorical_accuracy: 0.1783 - loss: 1.6101Inside For
# not last batch
# 20/23 ━━━━━━━━━━━━━━━━━━━━ 18s 6s/step - categorical_accuracy: 0.1794 - loss: 1.6101Inside For
# not last batch
# 21/23 ━━━━━━━━━━━━━━━━━━━━ 12s 6s/step - categorical_accuracy: 0.1805 - loss: 1.6100Inside For
# passing last batch
# came here num_batches: 23
# came here num_batches: 3
# Inside For
# not last batch
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - categorical_accuracy: 0.1827 - loss: 1.6100Inside For
# not last batch
# Inside For
# not last batch
# Inside For
# passing last batch
# came here num_batches: 4
# came here num_batches: 10
# Inside For
# not last batch
#
# Epoch 8: saving model to model_init_2024-12-1414_16_12.083301/model-00008-1.60933-0.20664-1.60967-0.21000.h5.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 150s 7s/step - categorical_accuracy: 0.1837 - loss: 1.6099 - val_categorical_accuracy: 0.2100 - val_loss: 1.6097 - learning_rate: 0.0020
# Epoch 9/10
# Inside For
# not last batch
#  2/23 ━━━━━━━━━━━━━━━━━━━━ 1:19 4s/step - categorical_accuracy: 0.1667 - loss: 1.6097Inside For
# not last batch
# Inside For
# not last batch
#  3/23 ━━━━━━━━━━━━━━━━━━━━ 2:01 6s/step - categorical_accuracy: 0.1704 - loss: 1.6096Inside For
# not last batch
#  4/23 ━━━━━━━━━━━━━━━━━━━━ 2:09 7s/step - categorical_accuracy: 0.1715 - loss: 1.6096Inside For
# not last batch
#  5/23 ━━━━━━━━━━━━━━━━━━━━ 2:01 7s/step - categorical_accuracy: 0.1772 - loss: 1.6095Inside For
# not last batch
#  6/23 ━━━━━━━━━━━━━━━━━━━━ 1:54 7s/step - categorical_accuracy: 0.1801 - loss: 1.6094Inside For
# not last batch
#  7/23 ━━━━━━━━━━━━━━━━━━━━ 1:47 7s/step - categorical_accuracy: 0.1836 - loss: 1.6093Inside For
# not last batch
#  8/23 ━━━━━━━━━━━━━━━━━━━━ 1:41 7s/step - categorical_accuracy: 0.1851 - loss: 1.6093Inside For
# not last batch
#  9/23 ━━━━━━━━━━━━━━━━━━━━ 1:33 7s/step - categorical_accuracy: 0.1868 - loss: 1.6092Inside For
# not last batch
# 10/23 ━━━━━━━━━━━━━━━━━━━━ 1:27 7s/step - categorical_accuracy: 0.1888 - loss: 1.6092Inside For
# not last batch
# 11/23 ━━━━━━━━━━━━━━━━━━━━ 1:20 7s/step - categorical_accuracy: 0.1906 - loss: 1.6092Inside For
# not last batch
# 12/23 ━━━━━━━━━━━━━━━━━━━━ 1:13 7s/step - categorical_accuracy: 0.1923 - loss: 1.6091Inside For
# not last batch
# 13/23 ━━━━━━━━━━━━━━━━━━━━ 1:06 7s/step - categorical_accuracy: 0.1937 - loss: 1.6091Inside For
# not last batch
# 14/23 ━━━━━━━━━━━━━━━━━━━━ 1:00 7s/step - categorical_accuracy: 0.1952 - loss: 1.6090Inside For
# not last batch
# 15/23 ━━━━━━━━━━━━━━━━━━━━ 53s 7s/step - categorical_accuracy: 0.1965 - loss: 1.6090 Inside For
# not last batch
# 16/23 ━━━━━━━━━━━━━━━━━━━━ 46s 7s/step - categorical_accuracy: 0.1974 - loss: 1.6090Inside For
# not last batch
# 17/23 ━━━━━━━━━━━━━━━━━━━━ 40s 7s/step - categorical_accuracy: 0.1978 - loss: 1.6090Inside For
# not last batch
# 18/23 ━━━━━━━━━━━━━━━━━━━━ 33s 7s/step - categorical_accuracy: 0.1982 - loss: 1.6090Inside For
# not last batch
# 19/23 ━━━━━━━━━━━━━━━━━━━━ 26s 7s/step - categorical_accuracy: 0.1987 - loss: 1.6090Inside For
# not last batch
# 20/23 ━━━━━━━━━━━━━━━━━━━━ 20s 7s/step - categorical_accuracy: 0.1990 - loss: 1.6090Inside For
# not last batch
# 21/23 ━━━━━━━━━━━━━━━━━━━━ 13s 7s/step - categorical_accuracy: 0.1993 - loss: 1.6090Inside For
# passing last batch
# came here num_batches: 23
# came here num_batches: 3
# Inside For
# not last batch
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - categorical_accuracy: 0.1998 - loss: 1.6090Inside For
# not last batch
# Inside For
# not last batch
# Inside For
# passing last batch
# came here num_batches: 4
# came here num_batches: 10
# Inside For
# not last batch
#
# Epoch 9: saving model to model_init_2024-12-1414_16_12.083301/model-00009-1.60929-0.20513-1.60899-0.22000.h5.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 158s 7s/step - categorical_accuracy: 0.2000 - loss: 1.6090 - val_categorical_accuracy: 0.2200 - val_loss: 1.6090 - learning_rate: 0.0020
# Epoch 10/10
# Inside For
# not last batch
#  2/23 ━━━━━━━━━━━━━━━━━━━━ 1:14 4s/step - categorical_accuracy: 0.1917 - loss: 1.6126Inside For
# not last batch
# Inside For
# not last batch
#  3/23 ━━━━━━━━━━━━━━━━━━━━ 2:00 6s/step - categorical_accuracy: 0.1944 - loss: 1.6123Inside For
# not last batch
#  4/23 ━━━━━━━━━━━━━━━━━━━━ 2:05 7s/step - categorical_accuracy: 0.1937 - loss: 1.6122Inside For
# not last batch
#  5/23 ━━━━━━━━━━━━━━━━━━━━ 1:58 7s/step - categorical_accuracy: 0.1937 - loss: 1.6123Inside For
# not last batch
#  6/23 ━━━━━━━━━━━━━━━━━━━━ 1:51 7s/step - categorical_accuracy: 0.1938 - loss: 1.6122Inside For
# not last batch
#  7/23 ━━━━━━━━━━━━━━━━━━━━ 1:43 6s/step - categorical_accuracy: 0.1920 - loss: 1.6122Inside For
# not last batch
#  8/23 ━━━━━━━━━━━━━━━━━━━━ 1:36 6s/step - categorical_accuracy: 0.1919 - loss: 1.6122Inside For
# not last batch
#  9/23 ━━━━━━━━━━━━━━━━━━━━ 1:29 6s/step - categorical_accuracy: 0.1916 - loss: 1.6121Inside For
# not last batch
# 10/23 ━━━━━━━━━━━━━━━━━━━━ 1:23 6s/step - categorical_accuracy: 0.1924 - loss: 1.6120Inside For
# not last batch
# 11/23 ━━━━━━━━━━━━━━━━━━━━ 1:18 7s/step - categorical_accuracy: 0.1931 - loss: 1.6119Inside For
# not last batch
# 12/23 ━━━━━━━━━━━━━━━━━━━━ 1:12 7s/step - categorical_accuracy: 0.1937 - loss: 1.6118Inside For
# not last batch
# 13/23 ━━━━━━━━━━━━━━━━━━━━ 1:05 7s/step - categorical_accuracy: 0.1942 - loss: 1.6116Inside For
# not last batch
# 14/23 ━━━━━━━━━━━━━━━━━━━━ 59s 7s/step - categorical_accuracy: 0.1948 - loss: 1.6116 Inside For
# not last batch
# 15/23 ━━━━━━━━━━━━━━━━━━━━ 52s 7s/step - categorical_accuracy: 0.1950 - loss: 1.6115Inside For
# not last batch
# 16/23 ━━━━━━━━━━━━━━━━━━━━ 46s 7s/step - categorical_accuracy: 0.1955 - loss: 1.6114Inside For
# not last batch
# 17/23 ━━━━━━━━━━━━━━━━━━━━ 39s 7s/step - categorical_accuracy: 0.1964 - loss: 1.6113Inside For
# not last batch
# 18/23 ━━━━━━━━━━━━━━━━━━━━ 33s 7s/step - categorical_accuracy: 0.1976 - loss: 1.6112Inside For
# not last batch
# 19/23 ━━━━━━━━━━━━━━━━━━━━ 26s 7s/step - categorical_accuracy: 0.1984 - loss: 1.6111Inside For
# not last batch
# 20/23 ━━━━━━━━━━━━━━━━━━━━ 20s 7s/step - categorical_accuracy: 0.1989 - loss: 1.6110Inside For
# not last batch
# 21/23 ━━━━━━━━━━━━━━━━━━━━ 13s 7s/step - categorical_accuracy: 0.1993 - loss: 1.6110Inside For
# passing last batch
# came here num_batches: 23
# came here num_batches: 3
# Inside For
# not last batch
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - categorical_accuracy: 0.2000 - loss: 1.6108Inside For
# not last batch
# Inside For
# not last batch
# Inside For
# passing last batch
# came here num_batches: 4
# came here num_batches: 10
# Inside For
# not last batch
#
# Epoch 10: saving model to model_init_2024-12-1414_16_12.083301/model-00010-1.60935-0.20814-1.60787-0.23000.h5.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 160s 7s/step - categorical_accuracy: 0.2003 - loss: 1.6108 - val_categorical_accuracy: 0.2300 - val_loss: 1.6079 - learning_rate: 0.0020
# Inside For
# not last batch

# %%
for i in range(1):
    print (i)
# Out:
# 0
